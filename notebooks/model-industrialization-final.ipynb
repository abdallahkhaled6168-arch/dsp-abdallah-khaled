# %%
# !rm -rf dsp-abdallah-khaled
# !git clone https://github.com/abdallahkhaled6168-arch/dsp-abdallah-khaled.git
# Out:
# Cloning into 'dsp-abdallah-khaled'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 187 (delta 40), reused 22 (delta 22), pack-reused 131 (from 1)
# Receiving objects: 100% (187/187), 493.52 KiB | 13.71 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
# %cd dsp-abdallah-khaled
# !ls
# Out:
# /content/dsp-abdallah-khaled
# data  notebooks  reports  requirements.txt

# %%
# !ls
# Out:
# data  notebooks  reports  requirements.txt

# %%
# %cd /content/dsp-abdallah-khaled
# !git fetch
# !git checkout pw2
# !git pull
# !ls
# Out:
# /content/dsp-abdallah-khaled
# Branch 'pw2' set up to track remote branch 'pw2' from 'origin'.
# Switched to a new branch 'pw2'
# Already up to date.
# data  house_prices  models  notebooks  reports	requirements.txt

# %%
import sys, os
sys.path.insert(0, os.getcwd())

# %%
from house_prices.train import build_model

metrics = build_model()
print("Model performance:", metrics)
# Out:
# Model performance: {'mse': 2234326445.289522}

# %%
from house_prices.inference import make_predictions

make_predictions()
# Out:
# Predictions file created successfully
